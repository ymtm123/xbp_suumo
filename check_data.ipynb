# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager

font_manager.fontManager.addfont("./fonts/ipaexg.ttf")
matplotlib.rc("font", family="IPAexGothic")

df = pd.read_csv("./data/yokohama_kawasaki.csv", index_col=0, encoding="utf-8")

# %%
df.columns
# Out:
# Index(['名称', 'カテゴリー', 'アドレス', 'アクセス', '路線', '駅', 'バス停', '乗換時間', 'バス', '徒歩',
#        '車', '合計時間', '築年数', '構造', '階数', '家賃', '管理費', '敷金', '礼金', '間取り', '面積',
#        'URL'],
#       dtype='object')

# %%
df
# Out:
#                               名称    カテゴリー             アドレス              アクセス  \
# 0                        ライトマルシェ   賃貸アパート  神奈川県横浜市鶴見区市場東中町   ＪＲ南武線/八丁畷駅 歩10分
# 1                        ライトマルシェ   賃貸アパート  神奈川県横浜市鶴見区市場東中町    京急本線/鶴見市場駅 歩1分
# 2                      ツインハウスフルヤ  賃貸マンション   神奈川県横浜市鶴見区潮田町２  ＪＲ京浜東北線/鶴見駅 歩15分
# 3      ＪＲ京浜東北線 鶴見駅 地下1地上5階建 築31年  賃貸マンション   神奈川県横浜市鶴見区潮田町２  ＪＲ鶴見線/鶴見小野駅 歩13分
# 4                            清美荘   賃貸アパート   神奈川県横浜市鶴見区江ケ崎町    ＪＲ南武線/矢向駅 歩12分
# ...                          ...      ...              ...               ...
# 80594                  Ｃａｓａ　Ｆ　南幸  賃貸マンション    神奈川県川崎市幸区南幸町３    ＪＲ南武線/矢向駅 歩15分
# 80595                       レンガ館  賃貸マンション  神奈川県川崎市中原区下小田中３  東急東横線/武蔵小杉駅 歩18分
# 80596                     サニーハウス   賃貸アパート     神奈川県川崎市多摩区登戸     小田急線/登戸駅 歩12分
# 80597                     サニーハウス   賃貸アパート     神奈川県川崎市多摩区登戸  小田急線/向ヶ丘遊園駅 歩12分
# 80598          小田急線 登戸駅 2階建 築23年   賃貸アパート     神奈川県川崎市多摩区登戸     小田急線/登戸駅 歩12分
#
#             路線       駅  バス停  乗換時間  バス  徒歩  ...  築年数  構造  階数    家賃  管理費    敷金  \
# 0        ＪＲ南武線    八丁畷駅  NaN    27   0  10  ...   14   3   1   6.0  0.0   6.0
# 1         京急本線   鶴見市場駅  NaN    26   0   1  ...   14   3   2   6.0  0.0   6.0
# 2      ＪＲ京浜東北線     鶴見駅  NaN    20   0  15  ...   31   5   4   7.5  1.0   0.0
# 3        ＪＲ鶴見線   鶴見小野駅  NaN    32   0  13  ...   31   5   4   7.5  1.0   0.0
# 4        ＪＲ南武線     矢向駅  NaN    29   0  12  ...   59   2   1   3.0  0.0   0.0
# ...        ...     ...  ...   ...  ..  ..  ...  ...  ..  ..   ...  ...   ...
# 80594    ＪＲ南武線     矢向駅  NaN    29   0  15  ...    5   5   2   7.9  0.6   7.9
# 80595    東急東横線   武蔵小杉駅  NaN    18   0  18  ...   34   3   3  11.5  0.0  11.5
# 80596     小田急線     登戸駅  NaN    47   0  12  ...   23   2   1   6.1  0.2   6.1
# 80597     小田急線  向ヶ丘遊園駅  NaN    55   0  12  ...   23   2   1   6.1  0.2   6.1
# 80598     小田急線     登戸駅  NaN    47   0  12  ...   23   2   1   6.1  0.2   6.1
#
#         礼金    間取り     面積                                                URL
# 0      6.0  ワンルーム  11.00  https://suumo.jp/chintai/jnc_000013653014/?bc=...
# 1      6.0  ワンルーム  11.56  https://suumo.jp/chintai/jnc_000013653015/?bc=...
# 2      7.5   1LDK  38.88  https://suumo.jp/chintai/jnc_000013653182/?bc=...
# 3      7.5   1LDK  38.88  https://suumo.jp/chintai/jnc_000013653183/?bc=...
# 4      0.0     1K  22.10  https://suumo.jp/chintai/jnc_000013653254/?bc=...
# ...    ...    ...    ...                                                ...
# 80594  7.9     1K  24.29  https://suumo.jp/chintai/jnc_000077813401/?bc=...
# 80595  0.0    3DK  55.00  https://suumo.jp/chintai/jnc_000077813426/?bc=...
# 80596  0.0     1K  27.00  https://suumo.jp/chintai/jnc_000077813458/?bc=...
# 80597  0.0     1K  27.00  https://suumo.jp/chintai/jnc_000077813459/?bc=...
# 80598  0.0     1K  27.00  https://suumo.jp/chintai/jnc_000077813460/?bc=...
#
# [80599 rows x 22 columns]

# %%
df.value_counts("構造", sort=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='構造'>
